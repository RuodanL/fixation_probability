# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mathtext as mathtext
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

mathtext.FontConstantsBase.sup1 = 0.25
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Arial"
plt.rcParams['mathtext.fontset'] = "custom"
plt.rcParams["mathtext.rm"] = "Arial"
plt.rcParams['mathtext.it'] = 'Arial:italic'

rows, cols = 2, 2
fig, ax = plt.subplots(rows, cols, sharey = 'row', figsize=(12,10))

N=25
r=np.arange(0.01,3.00,0.01)
fix_moran=(1-1/r)/(1-1/(r**N))                    #fixation probability for moran process
fix_empirical = np.loadtxt('club_membership.txt') #fixation probability for empirical hypergraph
fix_rand = np.loadtxt('rand_club_membership.txt') #fixation probability for randomized empirical hypergraph
fix_omp = np.loadtxt('omp_club_membership.txt')   #fixation probability one-mode projection of empirical hypergraph

#ax[0,0].set_title('ER, $q^*=0.1$, slow', fontsize=14)
ax[0,0].tick_params(labelsize=15)
ax[0,0].set_xlim([0.01, 3.0])
ax[0,0].set_xticks([0, 1, 2, 3])
ax[0,0].set_xticklabels(['0','1','2','3'])
ax[0,0].set_ylim([0.0, 0.8])
ax[0,0].set_yticks([0, 0.4, 0.8])
ax[0,0].set_yticklabels(['0', '0.4', '0.8'])
ax[0,0].scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
ax[0,0].scatter(r, fix_omp, label='one-mode projection', marker='.', s=10, color='magenta')
ax[0,0].scatter(r, fix_rand, label='randomized', marker='.', s=10, color='green')
ax[0,0].plot(r, fix_moran, label='Moran', linewidth=2, color='royalblue')
#legend_font = {'family' : 'Arial', 'weight' : 'normal', 'size': 12}
#ax[0,0].legend(prop=legend_font)
ax[0,0].legend(markerscale=4, fontsize=14, frameon=False)
fig.text(0.06, 0.895, '(a)', fontsize=20)
fig.text(0.25, 0.895, 'corporate', fontsize=20)

N=143
r=np.arange(0.01,3.00,0.01)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('email_enron.txt')
fix_rand = np.loadtxt('rand_email_enron.txt')
fix_omp = np.loadtxt('omp_email_enron_3k.txt')

#ax[0,1].set_title('ER, $q^*=0.1$, fast', fontsize=14)
ax[0,1].tick_params(labelsize=15)
ax[0,1].set_xlim([0.01, 3.0])
ax[0,1].set_xticks([0, 1, 2, 3])
ax[0,1].set_xticklabels(['0','1','2','3'])
ax[0,1].set_ylim([0.0, 0.8])
ax[0,1].set_yticks([0, 0.4, 0.8])
ax[0,1].set_yticklabels(['0', '0.4', '0.8'])
ax[0,1].scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
ax[0,1].scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
ax[0,1].scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
ax[0,1].plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')
fig.text(0.51, 0.895, '(b)', fontsize=20)
fig.text(0.7, 0.895, 'Enron', fontsize=20)

r=np.arange(0.98,1.00,0.0004)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('avr_email_enron_smallr.txt')
fix_rand = np.loadtxt('avr_rand_email_enron_smallr.txt')
fix_omp = np.loadtxt('avr_omp_email_enron_smallr.txt')

#inset_axes = inset_axes(ax[0,1], width="50%", height=0.8, loc=1)
inset_axes = fig.add_axes([0.6, 0.75, 0.11, 0.11])
inset_axes.tick_params(labelsize=12)
inset_axes.set_xlim([0.98, 1.0])
inset_axes.set_xticks([0.98, 0.99, 1])
inset_axes.set_xticklabels(['0.98', '0.99', '1'])
inset_axes.set_ylim([0.0, 0.01])
inset_axes.set_yticks([0, 0.005, 0.01])
inset_axes.set_yticklabels(['0', '0.005', '0.01'])
inset_axes.set_xlabel('$r$', fontsize=14)
inset_axes.scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
inset_axes.scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
inset_axes.scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
inset_axes.plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')


N=282
r=np.arange(0.01,3.00,0.01)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('senate_committees.txt')
fix_rand = np.loadtxt('rand_senate_committees.txt')
fix_omp = np.loadtxt('omp_senate_committees_3k.txt')

#ax[0,2].set_title('ER, $q^*=0.5$, slow', fontsize=14)
ax[1,0].tick_params(labelsize=15)
ax[1,0].set_xlim([0.01, 3.0])
ax[1,0].set_xticks([0, 1, 2, 3])
ax[1,0].set_xticklabels(['0','1','2','3'])
ax[1,0].set_ylim([0.0, 0.8])
ax[1,0].set_yticks([0, 0.4, 0.8])
ax[1,0].set_yticklabels(['0', '0.4', '0.8'])
ax[1,0].scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
ax[1,0].scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
ax[1,0].scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
ax[1,0].plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')
fig.text(0.06, 0.47, '(c)', fontsize=20)
fig.text(0.27, 0.47, 'Senate', fontsize=20)

r=np.arange(0.98,1.00,0.0004)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('avr_senate_committees_smallr.txt')
fix_rand = np.loadtxt('avr_rand_senate_committees_smallr.txt')
fix_omp = np.loadtxt('avr_omp_senate_committees_smallr.txt')

inset_axes = fig.add_axes([0.18, 0.295, 0.11, 0.11])
inset_axes.tick_params(labelsize=12)
inset_axes.set_xlim([0.98, 1.0])
inset_axes.set_xticks([0.98, 0.99, 1])
inset_axes.set_xticklabels(['0.98', '0.99', '1'])
inset_axes.set_ylim([0.0, 0.004])
inset_axes.set_yticks([0, 0.002, 0.004])
inset_axes.set_yticklabels(['0', '0.002', '0.004'])
inset_axes.set_xlabel('$r$', fontsize=14)
inset_axes.scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
inset_axes.scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
inset_axes.scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
inset_axes.plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')

N=327
r=np.arange(0.01,3.00,0.01)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('contact_high_school.txt')
fix_rand = np.loadtxt('rand_contact_high_school.txt')
fix_omp = np.loadtxt('omp_contact_high_school_3k.txt')

#ax[0,3].set_title('ER, $q^*=0.5$, fast', fontsize=14)
ax[1,1].tick_params(labelsize=15)
ax[1,1].set_xlim([0.01, 3.0])
ax[1,1].set_xticks([0, 1, 2, 3])
ax[1,1].set_xticklabels(['0','1','2','3'])
ax[1,1].set_ylim([0.0, 0.8])
ax[1,1].set_yticks([0, 0.4, 0.8])
ax[1,1].set_yticklabels(['0', '0.4', '0.8'])
ax[1,1].scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
ax[1,1].scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
ax[1,1].scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
ax[1,1].plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')
fig.text(0.51, 0.47, '(d)', fontsize=20)
fig.text(0.67, 0.47, 'high-school', fontsize=20)

r=np.arange(0.98,1.00,0.0004)
fix_moran=(1-1/r)/(1-1/(r**N))
fix_empirical = np.loadtxt('avr_contact_high_school_smallr.txt')
fix_rand = np.loadtxt('avr_rand_contact_high_school_smallr.txt')
fix_omp = np.loadtxt('avr_omp_contact_high_school_smallr.txt')

#inset_axes = inset_axes(ax[2,0], width="50%", height=0.8, loc=1)
inset_axes = fig.add_axes([0.6, 0.295, 0.11, 0.11])
inset_axes.tick_params(labelsize=12)
inset_axes.set_xlim([0.98, 1.0])
inset_axes.set_xticks([0.98, 0.99, 1])
inset_axes.set_xticklabels(['0.98', '0.99', '1'])
inset_axes.set_ylim([0.0, 0.002])
inset_axes.set_yticks([0, 0.001, 0.002])
inset_axes.set_yticklabels(['0', '0.001', '0.002'])
inset_axes.set_xlabel('$r$', fontsize=14)
inset_axes.scatter(r, fix_empirical, label='empirical', marker='.', s=10, color='orange')
inset_axes.scatter(r, fix_rand, label='random', marker='.', s=10, color='green')
inset_axes.scatter(r, fix_omp, label='omp', marker='.', s=10, color='magenta')
inset_axes.plot(r, fix_moran, label='moran', linewidth=2, color='royalblue')

fig.text(0.5, 0.072, '$r$', ha='center', va='center', fontsize=28)
fig.text(0.03, 0.5, 'Fixation probability', ha='center', va='center', rotation='vertical', fontsize=28)
plt.subplots_adjust(hspace=0.3)
#plt.tight_layout()
plt.savefig('empirical_hypergraph.pdf', bbox_inches="tight")
plt.show()
# Out:
# <ipython-input-1-5baa231a5c92>:18: RuntimeWarning: invalid value encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))                    #fixation probability for moran process
# <ipython-input-1-5baa231a5c92>:43: RuntimeWarning: invalid value encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# <ipython-input-1-5baa231a5c92>:87: RuntimeWarning: divide by zero encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# <ipython-input-1-5baa231a5c92>:87: RuntimeWarning: overflow encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# <ipython-input-1-5baa231a5c92>:87: RuntimeWarning: invalid value encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# <ipython-input-1-5baa231a5c92>:129: RuntimeWarning: divide by zero encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# <ipython-input-1-5baa231a5c92>:129: RuntimeWarning: overflow encountered in true_divide
#   fix_moran=(1-1/r)/(1-1/(r**N))
# ...
